# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/bank_data.csv')

# %%
df['Churn'] = df['Attrition_Flag'].apply(lambda val: 0 if val == "Existing Customer" else 1)

# %%
fig = df.Marital_Status.value_counts('normalize').plot(kind='bar').get_figure()
fig.savefig('./123456.jpg')

# %%
fig = df['Customer_Age'].hist().get_figure()
fig.savefig('./qwerty.png')

# %%
ax = df['Churn'].hist()
fig = ax.get_figure()
fig.savefig('./1.png')

# %%
fig = sns.heatmap(df.corr(), annot=False, cmap='Dark2_r', linewidths = 2).get_figure()
fig.savefig('./2.jpg')

# %%
fig = sns.distplot(df['Total_Trans_Ct']).get_figure()
fig.savefig('./123.jpg')

# %%
df['Churn'] = df['Attrition_Flag'].apply(lambda val: 0 if val == "Existing Customer" else 1)
df1 = df['Churn'].hist()
df2 = df['Customer_Age'].hist()
df3 = df.Marital_Status.value_counts('normalize').plot(kind='bar')
df5 = sns.distplot(df['Total_Trans_Ct'])
df4 = sns.heatmap(df.corr(), annot=False, cmap='Dark2_r', linewidths = 2)

df1.get_figure().savefig('./images/1.png')
df2.get_figure().savefig('./images/2.png')
df3.get_figure().savefig('./images/3.png')
df4.get_figure().savefig('./images/4.png')
df5.get_figure().savefig('./images/5.png')



#for i, plot in enumerate(plots):
#    plot.get_figure().savefig('./images/{}.png'.format(i))

# %%
plt.figure(1)
plt.subplot(2,3,1)
df1.A.plot() #no need to specify for first axis
plt.subplot(2,3,2)
df2.B.plot(ax=plt.gca())
plt.subplot(2,3,3)
df3.C.plot(ax=plt.gca())
plt.subplot(2,3,4)
df4.B.plot(ax=plt.gca())
plt.subplot(2,3,5)
df5.C.plot(ax=plt.gca())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-128534aa87f4> in <module>
#       1 plt.figure(1)
#       2 plt.subplot(2,3,1)
# ----> 3 df1.A.plot() #no need to specify for first axis
#       4 plt.subplot(2,3,2)
#       5 df2.B.plot(ax=plt.gca())
#
# AttributeError: 'AxesSubplot' object has no attribute 'A'

# %%
for plot in plots:
    print(type(plot))
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>
